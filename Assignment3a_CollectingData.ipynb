# %% [markdown]
# # U.S. Crime Rates and Statistics by Type and City

# %% [markdown]
# In this assignment, I will be exploring a datasets related to crime rates and types for U.S. cities. This dataset contains data from the years 1975 - 2015. First, I will import pandas...

# %%
import pandas as pd

# %% [markdown]
# Next, I will link my dataset so that it can be explored.

# %%
crime_df = pd.read_csv('C:/Users/josie/Downloads/Assignment3a/report.csv', delimiter=",", encoding='utf-8')

# %% [markdown]
# Now, I will display a sample of 10 rows of a dataframe to ensure that everything is working properly, and to see how the categories are organized and which categories exist.

# %%
crime_df.sample(10)
# Out:
#       report_year agency_code    agency_jurisdiction  population  \
# 645          1984     FL01602       Jacksonville, FL    582421.0
# 895          1987     KS08703            Wichita, KS    290702.0
# 337          1979     NY05101     Suffolk County, NY   1165851.0
# 1840         2001     FL04804            Orlando, FL    190769.0
# 560          1983     NY01401            Buffalo, NY    360656.0
# 2583         2012     KY05680         Louisville, KY    666200.0
# 2410         2009     OK07205              Tulsa, OK    384851.0
# 999          1989     FL01300  Miami-Dade County, FL    972785.0
# 2241         2007     FL01300  Miami-Dade County, FL   1082395.0
# 165          1977     CA01941         Long Beach, CA    346662.0
#
#       violent_crimes  homicides  rapes  assaults  robberies  months_reported  \
# 645           6228.0      103.0  587.0    3404.0     2134.0             12.0
# 895           1566.0       24.0  240.0     711.0      591.0             12.0
# ...

# %% [markdown]
# Now, it is important to isolate certain categories to discover outliers and averages. In order to formulate further research questions when evaluating data related to U.S. crime rates and types, certain questions need to be explored related to these outliers and averages.
#
# The first question to determine outliers is: Which cities have the highest crimes_percapita in 1975 v.s. 2015?
# (This will help to determine if there is a difference in the top cities with the highest crime rates per capita in the beginning of the sample dataset and in the last year data was available in the sample dataset.)

# %%
crime_df[crime_df['crimes_percapita'] > 1500]
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 2            1975     GAAPD00         Atlanta, GA    490584.0          8033.0
# 6            1975     MDBPD00       Baltimore, MD    864100.0         16086.0
# 7            1975     MA01301          Boston, MA    616120.0         11386.0
# 12           1975     OHCLP00       Cleveland, OH    659931.0         10403.0
# 16           1975     MI82349         Detroit, MI   1432444.0         30387.0
# ...           ...         ...                 ...         ...             ...
# 2766         2015     MDBPD00       Baltimore, MD    621252.0          9542.0
# 2776         2015     MI82349         Detroit, MI    673225.0         11846.0
# 2791         2015     TNMPD00         Memphis, TN    657936.0         11449.0
# 2795         2015     WIMPD00       Milwaukee, WI    600400.0          9583.0
# 2820         2015     MOSPD00       St. Louis, MO    317095.0          5762.0
#
# ...

# %% [markdown]
# Now, I will isolate a city that remains within the cities with the highest crimerates in order to explore it further.

# %%
baltimore = crime_df[crime_df['agency_jurisdiction'] == 'Baltimore, MD']

# %% [markdown]
# What years had the highest crimes_percaptia in Baltimore, MD?

# %%
highest_crime_year_baltimore = baltimore.sort_values(by='crimes_percapita', ascending=False)
highest_crime_year_baltimore[:20]
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 1386         1995     MDBPD00       Baltimore, MD    712209.0         21492.0
# 1248         1993     MDBPD00       Baltimore, MD    732968.0         21945.0
# 1179         1992     MDBPD00       Baltimore, MD    755517.0         21799.0
# 1662         1999     MDBPD00       Baltimore, MD    650588.0         18677.0
# 1317         1994     MDBPD00       Baltimore, MD    739180.0         20951.0
# 1455         1996     MDBPD00       Baltimore, MD    716446.0         19509.0
# 1110         1991     MDBPD00       Baltimore, MD    748099.0         19032.0
# 1731         2000     MDBPD00       Baltimore, MD    651154.0         16003.0
# 1041         1990     MDBPD00       Baltimore, MD    736014.0         17942.0
# 1524         1997     MDBPD00       Baltimore, MD    719587.0         17416.0
# 1593         1998     MDBPD00       Baltimore, MD    662253.0         16025.0
# ...

# %% [markdown]
# Now, we can create a table that displays the years that the robbery rates were the highest in Baltimore, MD, for instance, and ask the question:
#
# Which years were robbery rates the highest in Baltimore, MD from 1975 - 2015?

# %%
baltimore_robberies = baltimore[['report_year', 'robberies']]
top_20_robberies = baltimore_robberies.sort_values(by='robberies', ascending=False)[:20]
top_20_robberies[:20]
# Out:
#       report_year  robberies
# 1248         1993    12376.0
# 1179         1992    12263.0
# 1386         1995    11353.0
# 1317         1994    11275.0
# 1110         1991    10770.0
# 420          1981    10715.0
# 1455         1996    10393.0
# 351          1980    10020.0
# 1041         1990     9477.0
# 489          1982     9347.0
# 558          1983     9167.0
# 6            1975     9055.0
# 1524         1997     8629.0
# 282          1979     8482.0
# 213          1978     8097.0
# 627          1984     8002.0
# 765          1986     7989.0
# 972          1989     7966.0
# 696          1985     7771.0
# 75           1976     7755.0

# %% [markdown]
# That looks great, but let's visualize this better with a bar graph to see the fluctuations over time.

# %%
import matplotlib.pyplot as plt

top_20_robberies = baltimore_robberies.sort_values(by='robberies', ascending=False)[:20]

plt.figure(figsize=(10, 6))
plt.bar(top_20_robberies['report_year'], top_20_robberies['robberies'], color='skyblue')
plt.title('Top 20 Years with Highest Robbery Rates in Baltimore')
plt.xlabel('Year')
plt.ylabel('Robberies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()
